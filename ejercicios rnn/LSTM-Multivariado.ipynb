# %%
# Ejemplo pronóstico de serie temporal Univariada
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from numpy import array
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from numpy import array
# Out:
# Using TensorFlow backend.

# %%
df_dataset= pd.read_csv('datatraining_Occupancy.csv')
df_dataset.head()
# df_dataset.describe()
# Out:
#                   date  Temperature  Humidity  Light     CO2  HumidityRatio  \
# 1  2015-02-04 17:51:00        23.18   27.2720  426.0  721.25       0.004793
# 2  2015-02-04 17:51:59        23.15   27.2675  429.5  714.00       0.004783
# 3  2015-02-04 17:53:00        23.15   27.2450  426.0  713.50       0.004779
# 4  2015-02-04 17:54:00        23.15   27.2000  426.0  708.25       0.004772
# 5  2015-02-04 17:55:00        23.10   27.2000  426.0  704.50       0.004757
#
#    Occupancy
# 1          1
# 2          1
# 3          1
# 4          1
# 5          1

# %%
i = 1
# plot each column
plt.figure(figsize=(20, 15))
for counter in range(1,len(df_dataset.columns)):
    plt.subplot(len(df_dataset.columns), 1, i)
    plt.plot(df_dataset.values[:, counter], color = 'blue')
    plt.title(df_dataset.columns[counter], y=0.8, loc='right')
    i = i+1
plt.show()

# %%
# split a multivariate sequence into samples
def split_sequences(sequences, n_steps):
	X, y = list(), list()
	for i in range(len(sequences)):
		# find the end of this pattern
		end_ix = i + n_steps
		# check if we are beyond the dataset
		if end_ix >= len(sequences):
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequences[i:end_ix, :-1], sequences[end_ix, -1]
		X.append(seq_x)
		y.append(seq_y)
	return array(X), array(y)

# %%
from sklearn.preprocessing import MinMaxScaler

# choose a number of time steps
n_steps = 10

df_occup=df_dataset.iloc[:,1:].copy()
values = df_occup.values.astype(float)
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# split into samples
X, y = split_sequences(scaled, n_steps)


print(X.shape)
print(y.shape)
df_occup
# Out:
# (8133, 10, 5)
# (8133,)
#       Temperature   Humidity  Light         CO2  HumidityRatio  Occupancy
# 1       23.180000  27.272000  426.0  721.250000       0.004793          1
# 2       23.150000  27.267500  429.5  714.000000       0.004783          1
# 3       23.150000  27.245000  426.0  713.500000       0.004779          1
# 4       23.150000  27.200000  426.0  708.250000       0.004772          1
# 5       23.100000  27.200000  426.0  704.500000       0.004757          1
# 6       23.100000  27.200000  419.0  701.000000       0.004757          1
# 7       23.100000  27.200000  419.0  701.666667       0.004757          1
# 8       23.100000  27.200000  419.0  699.000000       0.004757          1
# 9       23.100000  27.200000  419.0  689.333333       0.004757          1
# 10      23.075000  27.175000  419.0  688.000000       0.004745          1
# 11      23.075000  27.150000  419.0  690.250000       0.004741          1
# 12      23.100000  27.100000  419.0  691.000000       0.004739          1
# 13      23.100000  27.166667  419.0  683.500000       0.004751          1
# 14      23.050000  27.150000  419.0  687.500000       0.004734          1
# 15      23.000000  27.125000  419.0  686.000000       0.004715          1
# 16      23.000000  27.125000  418.5  680.500000       0.004715          1
# 17      23.000000  27.200000    0.0  681.500000       0.004728          0
# 18      22.945000  27.290000    0.0  685.000000       0.004728          0
# 19      22.945000  27.390000    0.0  685.000000       0.004745          0
# 20      22.890000  27.390000    0.0  689.000000       0.004730          0
# 21      22.890000  27.390000    0.0  689.500000       0.004730          0
# 22      22.890000  27.390000    0.0  689.000000       0.004730          0
# 23      22.890000  27.445000    0.0  691.000000       0.004739          0
# 24      22.890000  27.500000    0.0  688.000000       0.004749          0
# 25      22.890000  27.500000    0.0  689.500000       0.004749          0
# 26      22.790000  27.445000    0.0  689.000000       0.004710          0
# 27      22.790000  27.500000    0.0  685.666667       0.004720          0
# 28      22.790000  27.500000    0.0  687.000000       0.004720          0
# 29      22.790000  27.500000    0.0  688.000000       0.004720          0
# 30      22.745000  27.500000    0.0  670.000000       0.004707          0
# ...           ...        ...    ...         ...            ...        ...
# 8114    20.700000  34.417500  419.0  568.750000       0.005203          1
# 8115    20.700000  34.090000  419.0  556.666667       0.005153          1
# 8116    20.700000  34.296667  419.0  548.000000       0.005184          1
# 8117    20.730000  34.466667  419.0  563.333333       0.005220          1
# 8118    20.745000  34.567500  426.0  593.750000       0.005240          1
# 8119    20.767500  34.717500  422.5  600.750000       0.005270          1
# 8120    20.790000  35.090000  426.0  623.000000       0.005335          1
# 8121    20.790000  34.972500  433.0  631.000000       0.005317          1
# 8122    20.790000  34.826667  433.0  636.000000       0.005295          1
# 8123    20.840000  35.195000  433.0  636.750000       0.005368          1
# 8124    20.890000  35.300000  433.0  663.000000       0.005401          1
# 8125    20.856667  35.096667  433.0  665.333333       0.005358          1
# 8126    20.890000  35.320000  433.0  669.500000       0.005404          1
# 8127    20.917500  35.475000  433.0  679.250000       0.005437          1
# 8128    20.890000  35.400000  433.0  684.666667       0.005416          1
# 8129    20.917500  35.717500  433.0  706.250000       0.005474          1
# 8130    20.958750  35.683750  433.0  712.625000       0.005483          1
# 8131    21.000000  35.650000  433.0  719.000000       0.005492          1
# 8132    21.000000  35.700000  433.0  730.250000       0.005500          1
# 8133    21.000000  35.760000  433.0  739.000000       0.005509          1
# 8134    21.000000  35.850000  433.0  756.250000       0.005523          1
# 8135    21.000000  35.700000  433.0  761.000000       0.005500          1
# 8136    21.025000  35.950000  433.0  763.000000       0.005547          1
# 8137    21.000000  35.860000  433.0  771.333333       0.005525          1
# 8138    21.050000  36.050000  433.0  780.250000       0.005571          1
# 8139    21.050000  36.097500  433.0  787.250000       0.005579          1
# 8140    21.050000  35.995000  433.0  789.500000       0.005563          1
# 8141    21.100000  36.095000  433.0  798.500000       0.005596          1
# 8142    21.100000  36.260000  433.0  820.333333       0.005621          1
# 8143    21.100000  36.200000  447.0  821.000000       0.005612          1
#
# [8143 rows x 6 columns]

# %%
# print(X)
# print(y)
# df_dataset.head(50)

# %%
# reshape from [samples, timesteps] into [samples, timesteps, features]
n_features = len(df_occup.columns)-1
n_features
# Out:
# 5

# %%
# split into train and test sets

def get_train_test(X, y, n_test):
    n_train = X.shape[0] - n_test
    train = X[:n_train, :, :]
    test = X[n_train:, :, :]

    # # split into input and outputs
    train_X, train_y = train, y[:n_train]
    test_X, test_y = test, y[n_train:]
    # reshape input to be 3D [samples, timesteps, features]
    print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
    
    return train_X, train_y, test_X, test_y

n_test=2000
train_X, train_y, test_X, test_y=get_train_test(X, y, n_test)
# Out:
# (6133, 10, 5) (6133,) (2000, 10, 5) (2000,)

# %%
from keras.layers import Bidirectional
# define model
# return_sequences=True
model = Sequential()
model.add(LSTM(128, activation='sigmoid', input_shape=(n_steps, n_features)))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

# fit model
history = model.fit(train_X, train_y, epochs=100, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=True)
# Out:
# Train on 6133 samples, validate on 2000 samples
# Epoch 1/100
#  - 2s - loss: 0.1215 - val_loss: 0.0673
# Epoch 2/100
#  - 1s - loss: 0.0460 - val_loss: 0.0829
# Epoch 3/100
#  - 1s - loss: 0.0317 - val_loss: 0.0985
# Epoch 4/100
#  - 1s - loss: 0.0279 - val_loss: 0.0919
# Epoch 5/100
#  - 1s - loss: 0.0260 - val_loss: 0.1373
# Epoch 6/100
#  - 1s - loss: 0.0269 - val_loss: 0.1182
# Epoch 7/100
#  - 1s - loss: 0.0261 - val_loss: 0.1387
# Epoch 8/100
#  - 1s - loss: 0.0264 - val_loss: 0.0849
# Epoch 9/100
#  - 1s - loss: 0.0262 - val_loss: 0.1470
# Epoch 10/100
#  - 1s - loss: 0.0260 - val_loss: 0.1039
# Epoch 11/100
#  - 1s - loss: 0.0258 - val_loss: 0.0936
# Epoch 12/100
#  - 1s - loss: 0.0251 - val_loss: 0.1231
# Epoch 13/100
#  - 1s - loss: 0.0270 - val_loss: 0.1015
# Epoch 14/100
#  - 1s - loss: 0.0245 - val_loss: 0.1093
# Epoch 15/100
#  - 1s - loss: 0.0247 - val_loss: 0.1012
# Epoch 16/100
#  - 1s - loss: 0.0251 - val_loss: 0.0768
# Epoch 17/100
#  - 1s - loss: 0.0248 - val_loss: 0.0946
# Epoch 18/100
#  - 1s - loss: 0.0249 - val_loss: 0.0787
# Epoch 19/100
#  - 1s - loss: 0.0250 - val_loss: 0.0807
# Epoch 20/100
#  - 1s - loss: 0.0240 - val_loss: 0.0951
# Epoch 21/100
#  - 1s - loss: 0.0240 - val_loss: 0.0786
# Epoch 22/100
#  - 1s - loss: 0.0235 - val_loss: 0.0727
# Epoch 23/100
#  - 1s - loss: 0.0246 - val_loss: 0.0981
# Epoch 24/100
#  - 1s - loss: 0.0236 - val_loss: 0.0890
# Epoch 25/100
#  - 1s - loss: 0.0238 - val_loss: 0.1142
# Epoch 26/100
#  - 1s - loss: 0.0232 - val_loss: 0.0802
# Epoch 27/100
#  - 1s - loss: 0.0235 - val_loss: 0.0665
# Epoch 28/100
#  - 1s - loss: 0.0227 - val_loss: 0.0718
# Epoch 29/100
#  - 1s - loss: 0.0233 - val_loss: 0.0840
# Epoch 30/100
#  - 1s - loss: 0.0229 - val_loss: 0.0862
# Epoch 31/100
#  - 1s - loss: 0.0227 - val_loss: 0.0667
# Epoch 32/100
#  - 1s - loss: 0.0218 - val_loss: 0.0705
# Epoch 33/100
#  - 1s - loss: 0.0222 - val_loss: 0.0721
# Epoch 34/100
#  - 1s - loss: 0.0212 - val_loss: 0.0719
# Epoch 35/100
#  - 1s - loss: 0.0202 - val_loss: 0.0500
# Epoch 36/100
#  - 1s - loss: 0.0201 - val_loss: 0.0696
# Epoch 37/100
#  - 1s - loss: 0.0188 - val_loss: 0.0510
# Epoch 38/100
#  - 1s - loss: 0.0178 - val_loss: 0.0431
# Epoch 39/100
#  - 1s - loss: 0.0178 - val_loss: 0.0505
# Epoch 40/100
#  - 1s - loss: 0.0171 - val_loss: 0.0424
# Epoch 41/100
#  - 1s - loss: 0.0166 - val_loss: 0.0556
# Epoch 42/100
#  - 2s - loss: 0.0172 - val_loss: 0.0469
# Epoch 43/100
#  - 2s - loss: 0.0160 - val_loss: 0.0384
# Epoch 44/100
#  - 2s - loss: 0.0163 - val_loss: 0.0407
# Epoch 45/100
#  - 2s - loss: 0.0160 - val_loss: 0.0426
# Epoch 46/100
#  - 2s - loss: 0.0161 - val_loss: 0.0482
# Epoch 47/100
#  - 2s - loss: 0.0160 - val_loss: 0.0505
# Epoch 48/100
#  - 2s - loss: 0.0164 - val_loss: 0.0479
# Epoch 49/100
#  - 2s - loss: 0.0158 - val_loss: 0.0500
# Epoch 50/100
#  - 2s - loss: 0.0157 - val_loss: 0.0440
# Epoch 51/100
#  - 2s - loss: 0.0158 - val_loss: 0.0402
# Epoch 52/100
#  - 2s - loss: 0.0156 - val_loss: 0.0360
# Epoch 53/100
#  - 2s - loss: 0.0155 - val_loss: 0.0338
# Epoch 54/100
#  - 2s - loss: 0.0158 - val_loss: 0.0323
# Epoch 55/100
#  - 2s - loss: 0.0157 - val_loss: 0.0429
# Epoch 56/100
#  - 2s - loss: 0.0156 - val_loss: 0.0490
# Epoch 57/100
#  - 2s - loss: 0.0152 - val_loss: 0.0367
# Epoch 58/100
#  - 2s - loss: 0.0154 - val_loss: 0.0319
# Epoch 59/100
#  - 2s - loss: 0.0154 - val_loss: 0.0382
# Epoch 60/100
#  - 2s - loss: 0.0150 - val_loss: 0.0356
# Epoch 61/100
#  - 2s - loss: 0.0152 - val_loss: 0.0384
# Epoch 62/100
#  - 2s - loss: 0.0147 - val_loss: 0.0325
# Epoch 63/100
#  - 2s - loss: 0.0149 - val_loss: 0.0413
# Epoch 64/100
#  - 2s - loss: 0.0144 - val_loss: 0.0315
# Epoch 65/100
#  - 2s - loss: 0.0146 - val_loss: 0.0342
# Epoch 66/100
#  - 2s - loss: 0.0147 - val_loss: 0.0408
# Epoch 67/100
#  - 2s - loss: 0.0147 - val_loss: 0.0387
# Epoch 68/100
#  - 2s - loss: 0.0146 - val_loss: 0.0328
# Epoch 69/100
#  - 2s - loss: 0.0147 - val_loss: 0.0516
# Epoch 70/100
#  - 2s - loss: 0.0144 - val_loss: 0.0327
# Epoch 71/100
#  - 2s - loss: 0.0143 - val_loss: 0.0414
# Epoch 72/100
#  - 2s - loss: 0.0147 - val_loss: 0.0463
# Epoch 73/100
#  - 2s - loss: 0.0140 - val_loss: 0.0386
# Epoch 74/100
#  - 1s - loss: 0.0141 - val_loss: 0.0502
# Epoch 75/100
#  - 1s - loss: 0.0137 - val_loss: 0.0291
# Epoch 76/100
#  - 1s - loss: 0.0139 - val_loss: 0.0351
# Epoch 77/100
#  - 1s - loss: 0.0140 - val_loss: 0.0300
# Epoch 78/100
#  - 1s - loss: 0.0139 - val_loss: 0.0355
# Epoch 79/100
#  - 1s - loss: 0.0134 - val_loss: 0.0297
# Epoch 80/100
#  - 1s - loss: 0.0140 - val_loss: 0.0346
# Epoch 81/100
#  - 1s - loss: 0.0135 - val_loss: 0.0301
# Epoch 82/100
#  - 1s - loss: 0.0135 - val_loss: 0.0472
# Epoch 83/100
#  - 1s - loss: 0.0132 - val_loss: 0.0332
# Epoch 84/100
#  - 1s - loss: 0.0131 - val_loss: 0.0340
# Epoch 85/100
#  - 1s - loss: 0.0133 - val_loss: 0.0459
# Epoch 86/100
#  - 1s - loss: 0.0131 - val_loss: 0.0372
# Epoch 87/100
#  - 1s - loss: 0.0130 - val_loss: 0.0385
# Epoch 88/100
#  - 1s - loss: 0.0127 - val_loss: 0.0475
# Epoch 89/100
#  - 1s - loss: 0.0127 - val_loss: 0.0563
# Epoch 90/100
#  - 1s - loss: 0.0131 - val_loss: 0.0400
# Epoch 91/100
#  - 1s - loss: 0.0129 - val_loss: 0.0382
# Epoch 92/100
#  - 1s - loss: 0.0128 - val_loss: 0.0414
# Epoch 93/100
#  - 1s - loss: 0.0123 - val_loss: 0.0277
# Epoch 94/100
#  - 1s - loss: 0.0125 - val_loss: 0.0375
# Epoch 95/100
#  - 1s - loss: 0.0125 - val_loss: 0.0327
# Epoch 96/100
#  - 1s - loss: 0.0121 - val_loss: 0.0360
# Epoch 97/100
#  - 1s - loss: 0.0124 - val_loss: 0.0386
# Epoch 98/100
#  - 1s - loss: 0.0121 - val_loss: 0.0257
# Epoch 99/100
#  - 1s - loss: 0.0123 - val_loss: 0.0398
# Epoch 100/100
#  - 1s - loss: 0.0125 - val_loss: 0.0316

# %%
from matplotlib import pyplot

pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
yhat_train = model.predict(train_X)
# print(yhat_train)
# print(train_y)

yhat_test = model.predict(test_X)
# print(yhat_test)
# print(test_y)

# %%
plt.figure(figsize=(10, 7))
plt.plot(df_dataset['date'][-n_test:], test_y, 'b-')
plt.plot(df_dataset['date'][-n_test:], yhat_test, 'r-')
plt.legend(); plt.xlabel('Date'); plt.ylabel('Occupancy')
plt.title('Date vs. Occupancy');
# Out:
# No handles with labels found to put in legend.
